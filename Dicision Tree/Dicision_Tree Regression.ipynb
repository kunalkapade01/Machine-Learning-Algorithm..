# %%
from sklearn.datasets import make_regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = make_regression( n_samples=100, n_features=2, n_targets=1)

# %%
data
# Out:
# (array([[ 1.53074175, -0.39848968],
#         [ 0.90414374,  0.56086012],
#         [ 1.41258392, -1.41505869],
#         [-1.60562393, -0.55072072],
#         [ 0.89491353, -0.85124274],
#         [ 1.22071058,  0.50245214],
#         [ 0.13660887, -2.51093379],
#         [ 0.37594274, -1.70269522],
#         [ 1.34776303,  0.04366241],
#         [-0.45867494, -0.86909332],
#         [-0.43651054, -0.38372554],
#         [ 0.1849853 , -0.39679857],
#         [-0.37318537, -0.88189085],
#         [-0.27568242,  0.73478001],
#         [ 0.79440675,  1.09975738],
#         [-1.22913301, -0.94903015],
#         [-1.98132276, -1.08747003],
#         [-2.15293022,  0.90477599],
#         [-0.20221411, -0.58480525],
#         [ 0.73938641,  0.55004576],
#         [-0.01414757, -0.91229485],
#         [ 1.21916281,  0.79512744],
#         [ 0.94905485,  0.51704611],
#         [-1.10235962, -1.16039892],
#         [ 0.60519513,  0.03948294],
#         [ 0.32215234,  1.70516706],
#         [-0.58504777, -0.1871134 ],
#         [ 0.02684236,  0.11224572],
#         [ 1.48568121,  0.81482358],
#         [ 2.14096204, -0.16473071],
#         [-0.95132335,  1.01920547],
#         [ 1.51697912, -0.17218564],
#         [ 3.26234268,  0.52264797],
#         [ 0.86792228, -0.70258091],
#         [ 0.84603319, -0.82591014],
#         [ 0.58934727,  0.24387476],
#         [ 0.54055181, -0.22621008],
#         [ 0.69474035,  1.2164696 ],
#         [ 0.31967808,  0.09572433],
#         [-1.33361276,  0.84629409],
#         [-0.78105315,  0.23405323],
#         [-1.68081431,  0.27257823],
#         [ 0.1251538 ,  0.53134908],
#         [ 1.40212138, -3.1654672 ],
#         [-0.22909863,  0.80374329],
#         [ 0.33963621, -0.31275511],
#         [ 0.02264845,  1.61495671],
#         [-0.25056186, -0.93584747],
#         [-0.48833962,  0.72519535],
#         [ 0.50987824, -0.63783554],
#         [-1.53766334, -0.14108707],
#         [ 0.19511345,  1.34926147],
#         [ 0.29742137,  0.92989259],
#         [-0.02189481,  0.91466765],
#         [-0.46214758, -0.68028986],
#         [ 0.6066476 ,  0.28255656],
#         [-1.51130209, -0.68200241],
#         [-0.31918182,  1.54780586],
#         [ 1.75914871, -0.83985007],
#         [ 0.60853674,  0.41531987],
#         [-0.44225235, -0.88394845],
#         [-0.31172962, -2.03155822],
#         [-0.29513711,  2.39087159],
#         [-1.14534966,  0.94658083],
#         [ 0.97728577, -1.40796717],
#         [ 0.44811158, -0.63785942],
#         [-0.14572849,  0.31147614],
#         [ 0.59352191, -1.73658786],
#         [-1.0659241 ,  1.78411964],
#         [ 0.49886406, -1.16270551],
#         [ 0.08551881,  0.78827194],
#         [-0.06979736,  0.62425838],
#         [ 0.49059516,  0.30558383],
#         [-1.53076626,  0.61179683],
#         [-0.97309643, -0.21381033],
#         [-0.88191002,  1.79570565],
#         [-0.10820283,  1.58635059],
#         [ 0.38629649,  3.37007199],
#         [-1.74543545, -1.88920423],
#         [-0.11466369,  0.12321867],
#         [-0.55845675,  1.05987022],
#         [ 0.24962993, -0.01518228],
#         [-0.1353243 ,  0.19397973],
#         [-0.0841958 ,  0.55874639],
#         [-0.70642063, -0.83822837],
#         [-0.52493168, -0.41377993],
#         [-1.4661499 ,  0.41545619],
#         [-0.5289725 ,  0.90846965],
#         [ 0.92233611, -0.74961923],
#         [ 0.47503011, -1.28925423],
#         [ 0.57978656, -2.00992426],
#         [ 0.15402943,  1.53723106],
#         [ 0.30078342, -1.23997733],
#         [ 0.50257554, -1.81429933],
#         [-0.01973321,  0.34743003],
#         [-0.57682789, -0.00615322],
#         [ 1.26554745,  0.50312398],
#         [ 1.16871937,  0.29391576],
#         [ 1.14952686, -0.06822298],
#         [-1.24038998,  2.01748956]]),
#  array([  58.65714145,   68.69686855,    9.34068552, -102.95295134,
#            7.85221743,   81.85397257, -100.62380554,  -54.22413057,
#           68.51696817,  -59.84899554,  -37.99629631,   -7.82106564,
#          -56.16863675,   17.78958485,   86.31593576, -101.36826774,
#         -144.48599928,  -67.77449102,  -35.00895767,   60.08679375,
#          -39.71367054,   94.29361236,   69.04412447, -104.13818096,
#           31.61666793,   88.85212943,  -36.93371413,    6.12757022,
#          108.31581571,   98.83047577,   -3.45892255,   67.65438167,
#          183.6807045 ,   12.87492547,    6.51832188,   39.57371833,
#           17.05762699,   86.37838647,   19.90238826,  -29.75845788,
#          -28.61552146,  -71.46311911,   28.91212232,  -66.03245666,
#           23.04244884,    3.42084716,   70.18320189,  -52.41208273,
#            6.8633473 ,   -2.06229789,  -82.07428298,   67.34957899,
#           54.47472683,   38.0327698 ,  -51.94659621,   42.08347319,
#         -103.90276157,   50.40727798,   51.07769503,   47.85448209,
#          -59.67213913, -102.29473335,   87.64981817,  -16.15971006,
#          -11.88247001,   -5.11781221,    6.11360846,  -44.91378604,
#           23.58517398,  -25.05289534,   37.93932425,   23.24461276,
#           37.32918722,  -49.53633109,  -57.26523519,   33.18053561,
#           62.48899407,  163.22340392, -167.10681502,   -0.40095104,
#           17.7081861 ,   11.69546623,    1.60341583,   19.73097676,
#          -70.7806171 ,  -43.65417849,  -54.7373681 ,   12.69164084,
#           13.55422417,  -31.64335659,  -57.28218567,   73.35635501,
#          -38.15291367,  -52.7345884 ,   13.88190226,  -28.78851009,
#           84.09998225,   70.36489439,   53.9290181 ,   24.93746531]))

# %%
x = data[0]
y = data[1]

# %%
plt.scatter(x[:,0], y, color='green', label="input")
plt.scatter(x[:,1], y, color='red', label="output")
plt.legend()
plt.show()

# %%
df = pd.DataFrame(x, columns=["col1","col2"])
df["target"] = y 
df.head()
# Out:
#        col1      col2      target
# 0  1.530742 -0.398490   58.657141
# 1  0.904144  0.560860   68.696869
# 2  1.412584 -1.415059    9.340686
# 3 -1.605624 -0.550721 -102.952951
# 4  0.894914 -0.851243    7.852217

# %%
df.isnull().sum()
# Out:
# col1      0
# col2      0
# target    0
# dtype: int64

# %%
from sklearn.tree import tree

# %%
DTR = DecisionTreeRegressor(max_depth=3)

# %%
DTR.fit(x, y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
import sklearn.tree as tree

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(DTR)
plt.show()
