# %% [markdown]
# # Linear_Regression Model :-

# %%
# Import library :
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Create a random data :
area = np.random.randint(500, 900, 40)
price = np.random.randint(30, 99, 40)

# %%
# Area data :
area
# Out:
# array([632, 666, 759, 775, 547, 693, 895, 569, 528, 739, 633, 873, 736,
#        554, 876, 618, 638, 801, 827, 669, 772, 510, 677, 525, 830, 677,
#        688, 586, 626, 868, 583, 855, 877, 563, 837, 824, 516, 834, 824,
#        845])

# %%
# price data :
price
# Out:
# array([73, 70, 40, 90, 30, 94, 57, 98, 77, 42, 60, 60, 68, 92, 96, 93, 52,
#        40, 67, 64, 36, 53, 59, 30, 48, 55, 33, 35, 48, 97, 74, 45, 50, 49,
#        49, 84, 83, 79, 47, 78])

# %%
#Sort the data :
area.sort()
price.sort()

# %%
area
# Out:
# array([510, 516, 525, 528, 547, 554, 563, 569, 583, 586, 618, 626, 632,
#        633, 638, 666, 669, 677, 677, 688, 693, 736, 739, 759, 772, 775,
#        801, 824, 824, 827, 830, 834, 837, 845, 855, 868, 873, 876, 877,
#        895])

# %%
price
# Out:
# array([30, 30, 33, 35, 36, 40, 40, 42, 45, 47, 48, 48, 49, 49, 50, 52, 53,
#        55, 57, 59, 60, 60, 64, 67, 68, 70, 73, 74, 77, 78, 79, 83, 84, 90,
#        92, 93, 94, 96, 97, 98])

# %%
# Plot the graph :
# %matplotlib inline
plt.scatter(area, price, marker="*", color="red")
plt.xlabel("Area in sqft")
plt.ylabel("price in lakh")
plt.title("Area vs price")
plt.savefig("linear data example.png")
plt.show()

# %%
# %matplotlib inline
plt.plot(area, price, "b-*")
plt.xlabel("Area in sqft")
plt.ylabel("price in lakh")
plt.title("Area vs price")
plt.savefig("linear data example.jpg")
plt.show()

# %%
# Create a column :
data = {"Area":area, "Price":price}

# %%
# Dataframe create :
df = pd.DataFrame(data)

# %%
#Fetch first 5 rows :
df.head()
# Out:
#    Area  Price
# 0   510     30
# 1   516     30
# 2   525     33
# 3   528     35
# 4   547     36

# %%
# Split the data into x and y :
x = df.drop("Price", axis=1)
y = df["Price"]

# %%
x.head()
# Out:
#    Area
# 0   510
# 1   516
# 2   525
# 3   528
# 4   547

# %%
y.head()
# Out:
# 0    30
# 1    30
# 2    33
# 3    35
# 4    36
# Name: Price, dtype: int32

# %%
# Import LR model :
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
# Fit the model :
model.fit(x, y)
# Out:
# LinearRegression()

# %%
# Score the model :
model.score(x, y)
# Out:
# 0.9689506304427628

# %%
# Predict the model :
model.predict([[632]])
# Out:
# array([49.71287373])

# %%
model.predict([[900]])
# Out:
# array([93.99933168])

# %%
model.predict([[1000]])
# Out:
# array([110.52412942])

# %%
pred = model.predict(x)

# %%
pred
# Out:
# array([29.55262048, 30.54410835, 32.03134014, 32.52708408, 35.66679565,
#        36.82353149, 38.31076329, 39.30225115, 41.61572284, 42.11146677,
#        47.39940205, 48.72138586, 49.71287373, 49.87812171, 50.70436159,
#        55.33130496, 55.82704889, 57.14903271, 57.14903271, 58.96676047,
#        59.79300035, 66.89866338, 67.39440731, 70.69936686, 72.84759057,
#        73.3433345 , 77.63978192, 81.4404854 , 81.4404854 , 81.93622933,
#        82.43197326, 83.09296517, 83.5887091 , 84.91069292, 86.5631727 ,
#        88.7113964 , 89.53763629, 90.03338022, 90.1986282 , 93.17309179])

# %%
# %matplotlib inline
plt.figure(figsize=(9, 6))
plt.title("Area vs price")
plt.xlabel("Area in sqf")
plt.ylabel("price in lakh")
plt.scatter(area, price, marker="*", color="green")
plt.plot(area, price, "r--")
plt.plot(area, pred, "b-")
plt.legend(["Actual line","Best fit line","Actual points"])
plt.savefig("Actual linear data.jpg")
plt.show()

# %%
# Find the coeficient and intercept :
coef = model.coef_
intercept = model.intercept_

# %%
coef
# Out:
# array([0.16524798])

# %%
intercept
# Out:
# -54.72384800590345

# %%
from sklearn.metrics import r2_score

# %%
# Find r2_score :
score = r2_score(y, pred)

# %%
score
# Out:
# 0.9689506304427628
